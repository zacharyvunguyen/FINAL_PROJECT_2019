# %%
from absenteeism_module import *
model = absenteeism_model('model', 'scaler')

model.load_and_clean_data('Testing_Absenteeism_predictions.csv')

model.predicted_outputs()
# Out:
# /Users/zacharyvunguyen/opt/anaconda3/envs/zachary2019/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zacharyvunguyen/opt/anaconda3/envs/zachary2019/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator StandardScaler from version 0.19.1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#      Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0           0         0         0         1            7
# 1           0         0         0         0            7
# 2           0         0         0         1            7
# 3           1         0         0         0            7
# 4           0         0         0         1            7
# ..        ...       ...       ...       ...          ...
# 695         1         0         0         0            5
# 696         1         0         0         0            5
# 697         1         0         0         0            5
# 698         0         0         0         1            5
# 699         0         0         0         1            5
#
#      Transportation Expense  Age  Body Mass Index  Education  Children  Pet  \
# 0                       289   33               30          0         2    1
# 1                       118   50               31          0         1    0
# 2                       179   38               31          0         0    0
# 3                       279   39               24          0         2    0
# 4                       289   33               30          0         2    1
# ..                      ...  ...              ...        ...       ...  ...
# 695                     179   40               22          1         2    0
# 696                     225   28               24          0         1    2
# 697                     330   28               25          1         0    0
# 698                     235   32               25          1         0    0
# 699                     291   40               25          0         1    1
#
#      Probability  Prediction
# 0       0.593426           1
# 1       0.087617           0
# 2       0.245968           0
# 3       0.871887           1
# 4       0.593426           1
# ..           ...         ...
# 695     0.635157           1
# 696     0.716547           1
# 697     0.865909           1
# 698     0.249980           0
# 699     0.389129           0
#
# [700 rows x 13 columns]

# %%
model.predicted_outputs().to_csv('Absenteeism_predictions.csv', index = False)
